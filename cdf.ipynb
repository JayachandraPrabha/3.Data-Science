# %%
import pandas as pd

# %%
dataset=pd.read_csv('PrePlacement.csv')
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  390000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  390000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
# dataset.isna().sum()
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
def pdfGraph(dataset,startrange,endrange):
    import seaborn as sns
    import matplotlib.pyplot as plt
    from scipy.stats import norm

    graph=sns.distplot(dataset,kde=True,kde_kws={'color':'Blue'},color='Green')
    plt.axvline(startrange,color='Red')
    plt.axvline(endrange,color='Red')

    sample=dataset

    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean:{}, Std_Dev:{}'.format(sample_mean,sample_std))

    dist=norm(sample_mean,sample_std)

    values=[]
    for value in range(startrange,endrange):
        values.append(value)

    probabilities=[]
    for value in values:
        probabilities.append(dist.pdf(value))

    prob=sum(probabilities)
    print('The area between the range:({},{}:{})'.format(startrange,endrange,sum(probabilities)))
    return prob

# %%
pdfGraph(dataset['ssc_p'],60,70)
# Out:
# C:\Users\jayac\AppData\Local\Temp\ipykernel_8404\1578387533.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   graph=sns.distplot(dataset,kde=True,kde_kws={'color':'Blue'},color='Green')
# Mean:67.30339534883721, Std_Dev:10.827205398231452
# The area between the range:(60,70:0.3449514151280293)
# 0.3449514151280293

# %%
# !pip install statsmodels
# Out:
# ...
#      ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.2 MB 262.6 kB/s eta 0:00:35
#      ---------------------------------------- 0.0/9.2 MB 281.8 kB/s eta 0:00:33
#      ---------------------------------------- 0.1/9.2 MB 297.7 kB/s eta 0:00:31
#      ---------------------------------------- 0.1/9.2 MB 280.5 kB/s eta 0:00:33
#      ---------------------------------------- 0.1/9.2 MB 327.7 kB/s eta 0:00:28
#      ---------------------------------------- 0.1/9.2 MB 327.2 kB/s eta 0:00:28
#       --------------------------------------- 0.1/9.2 MB 313.8 kB/s eta 0:00:29
#       --------------------------------------- 0.1/9.2 MB 327.9 kB/s eta 0:00:28
#       --------------------------------------- 0.2/9.2 MB 305.7 kB/s eta 0:00:30
#       --------------------------------------- 0.2/9.2 MB 305.7 kB/s eta 0:00:30
# ...

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf=ECDF(dataset['ssc_p'])
ecdf(79)
# Out:
# 0.8465116279069768

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf=ECDF(dataset['ssc_p'])
ecdf(70)
# Out:
# 0.6093023255813953

# %%
def pdff(dataset,startrange,endrange):
    import seaborn as sns
    import matplotlib.pyplot as plt
    from scipy.stats import norm

    graph=sns.distplot(dataset,kde=True,kde_kws={'color':'Black'},color="Red")
    plt.axvline(startrange,color='Green')
    plt.axvline(endrange,color='Green')

    sample=dataset

    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean:{},Std:{}'.format(sample_mean,sample_std))

    dist=norm(sample_mean,sample_std)

    values=[]
    for value in range(startrange,endrange):
        values.append(value)

    probabilities=[]    
    for value in values:
        probabilities.append(dist.pdf(value))

    prob=sum(probabilities)
    print('The area between the range:({},{} : {})'.format(startrange,endrange,sum(probabilities)))
    return prob

# %%
pdff(dataset['hsc_p'],60,80)
# Out:
# Mean:66.33474418604652,Std:10.586015806645694
# The area between the range:(60,80 : 0.6340914171322534)
# C:\Users\jayac\AppData\Local\Temp\ipykernel_8404\649092740.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   graph=sns.distplot(dataset,kde=True,kde_kws={'color':'Black'},color="Red")
# 0.6340914171322534

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf=ECDF(dataset['hsc_p'])
ecdf(65)
# Out:
# 0.5162790697674419
